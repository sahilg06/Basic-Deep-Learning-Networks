# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from random import uniform

# %%
# Check Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define Hyper-parameters 
input_size = 784
hidden_size = 50
num_classes = 10
num_epochs = 2
batch_size = 32
learning_rate = 0.006

# %%
train_dataset = torchvision.datasets.MNIST(root='../../data', 
                                           train=True, 
                                           transform=transforms.ToTensor(),  
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='../../data', 
                                          train=False, 
                                          transform=transforms.ToTensor())

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../../data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../../data/MNIST/raw/train-images-idx3-ubyte.gz to ../../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../../data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../../data/MNIST/raw
# Processing...
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# Done!

# %%
# Fully connected neural network
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.bn1 = nn.BatchNorm1d(hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.bn2  = nn.BatchNorm1d(hidden_size)
        self.fc3 =  nn.Linear(hidden_size, num_classes)

    
    def forward(self, x):
        out = self.fc1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu(out)
        out = self.bn2(out)
        out = self.fc3(out)
        return out

model = NeuralNet(input_size, hidden_size, num_classes).to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Train the model
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):  
        # Move tensors to the configured device
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backprpagation and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))

            with torch.no_grad():
                correct = 0
                total = 0
                for images, labels in test_loader:
                    images = images.reshape(-1, 28*28).to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

                print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))

            with torch.no_grad():
                correct = 0
                total = 0
                for images, labels in train_loader:
                    images = images.reshape(-1, 28*28).to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

                print('Accuracy of the network on the 60000 train images: {} %'.format(100 * correct / total))
# Out:
# Epoch [1/2], Step [100/1875], Loss: 0.4144
# Accuracy of the network on the 10000 test images: 88.71 %
# Accuracy of the network on the 60000 train images: 87.87333333333333 %
# Epoch [1/2], Step [200/1875], Loss: 0.6105
# Accuracy of the network on the 10000 test images: 90.19 %
# Accuracy of the network on the 60000 train images: 89.525 %
# Epoch [1/2], Step [300/1875], Loss: 0.1882
# Accuracy of the network on the 10000 test images: 92.21 %
# Accuracy of the network on the 60000 train images: 91.36166666666666 %
# Epoch [1/2], Step [400/1875], Loss: 0.2092
# Accuracy of the network on the 10000 test images: 92.46 %
# Accuracy of the network on the 60000 train images: 92.155 %
# Epoch [1/2], Step [500/1875], Loss: 0.1333
# Accuracy of the network on the 10000 test images: 92.85 %
# Accuracy of the network on the 60000 train images: 92.66833333333334 %
# Epoch [1/2], Step [600/1875], Loss: 0.1497
# Accuracy of the network on the 10000 test images: 92.87 %
# Accuracy of the network on the 60000 train images: 92.86166666666666 %
# Epoch [1/2], Step [700/1875], Loss: 0.4871
# Accuracy of the network on the 10000 test images: 93.03 %
# Accuracy of the network on the 60000 train images: 92.67 %
# Epoch [1/2], Step [800/1875], Loss: 0.2740
# Accuracy of the network on the 10000 test images: 93.49 %
# Accuracy of the network on the 60000 train images: 93.44166666666666 %
# Epoch [1/2], Step [900/1875], Loss: 0.3135
# Accuracy of the network on the 10000 test images: 94.05 %
# Accuracy of the network on the 60000 train images: 93.62 %
# Epoch [1/2], Step [1000/1875], Loss: 0.1773
# Accuracy of the network on the 10000 test images: 94.12 %
# Accuracy of the network on the 60000 train images: 93.63 %
# Epoch [1/2], Step [1100/1875], Loss: 0.2619
# Accuracy of the network on the 10000 test images: 94.02 %
# Accuracy of the network on the 60000 train images: 94.05333333333333 %
# Epoch [1/2], Step [1200/1875], Loss: 0.0873
# Accuracy of the network on the 10000 test images: 94.39 %
# Accuracy of the network on the 60000 train images: 94.645 %
# Epoch [1/2], Step [1300/1875], Loss: 0.1413
# Accuracy of the network on the 10000 test images: 94.36 %
# Accuracy of the network on the 60000 train images: 94.70833333333333 %
# Epoch [1/2], Step [1400/1875], Loss: 0.3079
# Accuracy of the network on the 10000 test images: 94.3 %
# Accuracy of the network on the 60000 train images: 94.84666666666666 %
# Epoch [1/2], Step [1500/1875], Loss: 0.2267
# Accuracy of the network on the 10000 test images: 94.04 %
# Accuracy of the network on the 60000 train images: 94.245 %
# Epoch [1/2], Step [1600/1875], Loss: 0.2698
# Accuracy of the network on the 10000 test images: 94.36 %
# Accuracy of the network on the 60000 train images: 94.85833333333333 %
# Epoch [1/2], Step [1700/1875], Loss: 0.1011
# Accuracy of the network on the 10000 test images: 94.36 %
# Accuracy of the network on the 60000 train images: 95.11333333333333 %
# Epoch [1/2], Step [1800/1875], Loss: 0.2228
# Accuracy of the network on the 10000 test images: 94.19 %
# Accuracy of the network on the 60000 train images: 94.94333333333333 %
# Epoch [2/2], Step [100/1875], Loss: 0.3580
# Accuracy of the network on the 10000 test images: 94.9 %
# Accuracy of the network on the 60000 train images: 95.26166666666667 %
# Epoch [2/2], Step [200/1875], Loss: 0.1705
# Accuracy of the network on the 10000 test images: 94.34 %
# Accuracy of the network on the 60000 train images: 95.035 %
# Epoch [2/2], Step [300/1875], Loss: 0.2169
# Accuracy of the network on the 10000 test images: 93.69 %
# Accuracy of the network on the 60000 train images: 94.79166666666667 %
# Epoch [2/2], Step [400/1875], Loss: 0.2934
# Accuracy of the network on the 10000 test images: 94.81 %
# Accuracy of the network on the 60000 train images: 95.51 %
# Epoch [2/2], Step [500/1875], Loss: 0.1250
# Accuracy of the network on the 10000 test images: 94.62 %
# Accuracy of the network on the 60000 train images: 95.44333333333333 %
# Epoch [2/2], Step [600/1875], Loss: 0.5052
# Accuracy of the network on the 10000 test images: 94.89 %
# Accuracy of the network on the 60000 train images: 95.635 %
# Epoch [2/2], Step [700/1875], Loss: 0.1324
# Accuracy of the network on the 10000 test images: 94.51 %
# Accuracy of the network on the 60000 train images: 95.61333333333333 %
# Epoch [2/2], Step [800/1875], Loss: 0.0595
# Accuracy of the network on the 10000 test images: 94.83 %
# Accuracy of the network on the 60000 train images: 95.52333333333333 %
# Epoch [2/2], Step [900/1875], Loss: 0.0316
# Accuracy of the network on the 10000 test images: 94.91 %
# Accuracy of the network on the 60000 train images: 95.555 %
# Epoch [2/2], Step [1000/1875], Loss: 0.2496
# Accuracy of the network on the 10000 test images: 93.98 %
# Accuracy of the network on the 60000 train images: 94.60166666666667 %
# Epoch [2/2], Step [1100/1875], Loss: 0.1823
# Accuracy of the network on the 10000 test images: 95.06 %
# Accuracy of the network on the 60000 train images: 95.97 %
# Epoch [2/2], Step [1200/1875], Loss: 0.1262
# Accuracy of the network on the 10000 test images: 94.83 %
# Accuracy of the network on the 60000 train images: 95.60666666666667 %
# Epoch [2/2], Step [1300/1875], Loss: 0.3043
# Accuracy of the network on the 10000 test images: 95.06 %
# Accuracy of the network on the 60000 train images: 96.17666666666666 %
# Epoch [2/2], Step [1400/1875], Loss: 0.0531
# Accuracy of the network on the 10000 test images: 94.4 %
# Accuracy of the network on the 60000 train images: 95.43333333333334 %
# Epoch [2/2], Step [1500/1875], Loss: 0.0280
# Accuracy of the network on the 10000 test images: 95.15 %
# Accuracy of the network on the 60000 train images: 95.95833333333333 %
# Epoch [2/2], Step [1600/1875], Loss: 0.1366
# Accuracy of the network on the 10000 test images: 94.89 %
# Accuracy of the network on the 60000 train images: 95.61166666666666 %
# Epoch [2/2], Step [1700/1875], Loss: 0.0997
# Accuracy of the network on the 10000 test images: 95.15 %
# Accuracy of the network on the 60000 train images: 96.04166666666667 %
# Epoch [2/2], Step [1800/1875], Loss: 0.0788
# Accuracy of the network on the 10000 test images: 95.3 %
# Accuracy of the network on the 60000 train images: 96.16333333333333 %

# %%
# Test the model
# In the test phase, don't need to compute gradients (for memory efficiency)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))

# Save the model checkpoint
torch.save(model.state_dict(), 'model.ckpt')
# Out:
# Accuracy of the network on the 10000 test images: 95.2 %

# %%
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in train_loader:
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print('Accuracy of the network on the 60000 train images: {} %'.format(100 * correct / total))

# Save the model checkpoint
torch.save(model.state_dict(), 'model.ckpt')
# Out:
# Accuracy of the network on the 60000 train images: 96.21666666666667 %
